# %% [markdown]
# # Case Study: Causal Discovery (i.i.d. data)
#
# Figure 5

# %% [markdown]
# Directory to store the downloaded causal chamber datasets.

# %%
DOWNLOAD_DIR = '/tmp'

# %%
import sys
sys.path = ['../'] + sys.path

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import sempler.plot
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Auxiliary Code

# %% [markdown]
# #### Plot settings

# %%
matplotlib.rc('text', usetex = True)
matplotlib.rc('font', **{'family' : "sans-serif"})
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

matplotlib.rcParams.update({'font.size': 7})
MM = 1/25.4 # inches to mm

def to_rgb(H, b=1, a=1):
    RGBa = []
    for h in H:
        h = h.lstrip("#")
        RGBa.append(tuple(int(h[i:i+2], 16) / 256 * b for i in (0, 2, 4)) + (a,))
    return np.array(RGBa)

# Color palettes
color_blind_1 = ['#d73027', '#fc8d59', '#fee090', '#91bfdb', '#4575b4', '#020202',]
color_blind_2 = ['#b2182b', '#d6604d', '#f4a582', '#fddbc7', '#d1e5f0', '#92c5de', '#4393c3', '#2166ac']
color_blind_3 = ['#8c510a', '#bf812d', '#dfc27d', '#f6e8c3', '#c7eae5', '#80cdc1', '#35978f', '#01665e']
ibm_color_blind = ["#648fff", "#785ef0", "#dc267f", "#fe6100", "#ffb000", "#000000", "#ffffff"]
rainbow10 = ["#ff4365", "#ffdd43", "#59ff43", "#43ffdd", "#7395ff", "#4365ff", "#e943ff", "#601e9e", "#6a6a6a", "#964b00"]


# Pick one and show

palette = ibm_color_blind

base = to_rgb(palette)
basea = to_rgb(palette, a=0.5)
baseb = to_rgb(palette, b=0.7)
plt.scatter(np.arange(len(base)), np.zeros(len(base)), c = base)
plt.scatter(np.arange(len(base)), np.ones(len(base))*0.5, c = basea)
plt.scatter(np.arange(len(base)), np.ones(len(base))*-0.5, c = baseb)

# %% [markdown]
# ### Metrics for ground-truth effect recovery
#
# Precision: $\frac{TP}{TP+FP}\quad\quad$ Recall: $\frac{TP}{P}$

# %%
def precision(estimate, truth):
    # TP = edges in estimate that are also in truth
    # FP + TP = total edges in estimate
    return np.logical_and(estimate,truth).sum() / estimate.sum()

def recall(estimate, truth):
    # TP = edges in estimate that are also in truth
    # P = total edges in truth
    return np.logical_and(estimate,truth).sum() / truth.sum()

# %% [markdown]
# ## Define ground-truth graph

# %%
import causalchamber
from causalchamber.utils import graph_to_tikz
from causalchamber.ground_truth import latex_name
# Out:
# Fetching list of available datasets from
#   https://causalchamber.s3.eu-central-1.amazonaws.com/downloadables/directory.yaml ... done.
#
#
# Citation
# --------
#
# If you use our datasets, simulators or Remote Lab for your work, please consider citing:
#
# ﻿@article{gamella2025chamber,
#   author={Gamella, Juan L. and Peters, Jonas and B{"u}hlmann, Peter},
#   title={Causal chambers as a real-world physical testbed for {AI} methodology},
#   journal={Nature Machine Intelligence},
#   doi={10.1038/s42256-024-00964-x},
#   year={2025},
# }
#
#
# Support & feedback
# ------------------
#
# If you encounter bugs o have feedback, please write us an email at
#
#   support@causalchamber.ai
#
# or leave an issue at
#
#   https://github.com/juangamella/causal-chamber-package/issues
#
# If you are a Remote Lab subscriber, contact us directly through any of
# the provided support channels.

# %% [markdown]
# For standard configuration of the light tunnel we can simply take the subgraph induced by the variables we use (this is not the case for e.g. linked configuration)

# %%
variables = ['red', 'green', 'blue', 'current', 'ir_1', 'ir_2', 'ir_3', 'vis_1', 'vis_2', 'vis_3', 'pol_1', 'pol_2', 'angle_1', 'angle_2', 'l_11', 'l_12', 'l_21', 'l_22', 'l_31', 'l_32']

# %%
# Ground truth graph
true_dag = causalchamber.ground_truth.graph('lt', 'standard').loc[variables, variables].values
sempler.plot.plot_graph(true_dag, labels = variables)
print(graph_to_tikz(true_dag, radius=1.7, labels=[latex_name(v) for v in variables]))
# Out:
#     \begin{tikzpicture}
#         \node[circle, inner sep=0.12em] (0) at (-0.525, 1.617) {$R$};
#         \node[circle, inner sep=0.12em] (1) at (-0.999, 1.375) {$G$};
#         \node[circle, inner sep=0.12em] (2) at (-1.375, 0.999) {$B$};
#         \node[circle, inner sep=0.12em] (3) at (-1.617, 0.525) {$\tilde{C}$};
#         \node[circle, inner sep=0.12em] (4) at (-1.700, -0.000) {$\tilde{I}_1$};
#         \node[circle, inner sep=0.12em] (5) at (-1.617, -0.525) {$\tilde{I}_2$};
#         \node[circle, inner sep=0.12em] (6) at (-1.375, -0.999) {$\tilde{I}_3$};
#         \node[circle, inner sep=0.12em] (7) at (-0.999, -1.375) {$\tilde{V}_1$};
#         \node[circle, inner sep=0.12em] (8) at (-0.525, -1.617) {$\tilde{V}_2$};
#         \node[circle, inner sep=0.12em] (9) at (0.000, -1.700) {$\tilde{V}_3$};
#         \node[circle, inner sep=0.12em] (10) at (0.525, -1.617) {$\theta_1$};
#         \node[circle, inner sep=0.12em] (11) at (0.999, -1.375) {$\theta_2$};
#         \node[circle, inner sep=0.12em] (12) at (1.375, -0.999) {$\tilde{\theta}_1$};
#         \node[circle, inner sep=0.12em] (13) at (1.617, -0.525) {$\tilde{\theta}_2$};
#         \node[circle, inner sep=0.12em] (14) at (1.700, 0.000) {$L_{11}$};
#         \node[circle, inner sep=0.12em] (15) at (1.617, 0.525) {$L_{12}$};
#         \node[circle, inner sep=0.12em] (16) at (1.375, 0.999) {$L_{21}$};
#         \node[circle, inner sep=0.12em] (17) at (0.999, 1.375) {$L_{22}$};
#         \node[circle, inner sep=0.12em] (18) at (0.525, 1.617) {$L_{31}$};
#         \node[circle, inner sep=0.12em] (19) at (0.000, 1.700) {$L_{32}$};
#         \begin{scope}[]
#             \draw[->] (0) edge (3);
#             \draw[->] (0) edge (4);
#             \draw[->] (0) edge (5);
#             \draw[->] (0) edge (6);
#             \draw[->] (0) edge (7);
#             \draw[->] (0) edge (8);
#             \draw[->] (0) edge (9);
#             \draw[->] (1) edge (3);
#             \draw[->] (1) edge (4);
#             \draw[->] (1) edge (5);
#             \draw[->] (1) edge (6);
#             \draw[->] (1) edge (7);
#             \draw[->] (1) edge (8);
#             \draw[->] (1) edge (9);
#             \draw[->] (2) edge (3);
#             \draw[->] (2) edge (4);
#             \draw[->] (2) edge (5);
#             \draw[->] (2) edge (6);
#             \draw[->] (2) edge (7);
#             \draw[->] (2) edge (8);
#             \draw[->] (2) edge (9);
#             \draw[->] (10) edge (6);
#             \draw[->] (10) edge (9);
#             \draw[->] (10) edge (12);
#             \draw[->] (11) edge (6);
#             \draw[->] (11) edge (9);
#             \draw[->] (11) edge (13);
#             \draw[->] (14) edge (4);
#             \draw[->] (14) edge (7);
#             \draw[->] (15) edge (4);
#             \draw[->] (15) edge (7);
#             \draw[->] (16) edge (5);
#             \draw[->] (16) edge (8);
#             \draw[->] (17) edge (5);
#             \draw[->] (17) edge (8);
#             \draw[->] (18) edge (6);
#             \draw[->] (18) edge (9);
#             \draw[->] (19) edge (6);
#             \draw[->] (19) edge (9);
#         \end{scope}
#     \end{tikzpicture}

# %% [markdown]
# ## Download dataset

# %%
from causalchamber.datasets import Dataset
dataset = Dataset(name="lt_interventions_standard_v1", root='')
# Out:
# Dataset lt_interventions_standard_v1 found in "lt_interventions_standard_v1".

# %%
experiments = [
    "uniform_reference",
    "uniform_red_strong",
    "uniform_green_strong",
    "uniform_blue_strong",
    "uniform_v_c_strong",
    "uniform_t_ir_1_strong",
    "uniform_t_ir_2_strong",
    "uniform_t_ir_3_strong",
    "uniform_t_vis_1_strong",
    "uniform_t_vis_2_strong",
    "uniform_t_vis_3_strong",
    "uniform_pol_1_strong",
    "uniform_pol_2_strong",
    "uniform_v_angle_1_strong",
    "uniform_v_angle_2_strong",
    "uniform_l_11_mid",
    "uniform_l_12_mid",
    "uniform_l_21_mid",
    "uniform_l_22_mid",
    "uniform_l_31_mid",
    "uniform_l_32_mid",
    
]
observational_data = dataset.get_experiment(experiments[0]).as_pandas_dataframe()[variables].values
interventional_data = [dataset.get_experiment(e).as_pandas_dataframe()[variables].values for e in experiments]

# %%
print("Sample sizes:")
for e,df in zip(experiments,interventional_data):
    print(f"  {len(df):<5}  {e}")
# Out:
# Sample sizes:
#   10000  uniform_reference
#   1000   uniform_red_strong
#   1000   uniform_green_strong
#   1000   uniform_blue_strong
#   1000   uniform_v_c_strong
#   1000   uniform_t_ir_1_strong
#   1000   uniform_t_ir_2_strong
#   1000   uniform_t_ir_3_strong
#   1000   uniform_t_vis_1_strong
#   1000   uniform_t_vis_2_strong
#   1000   uniform_t_vis_3_strong
#   1000   uniform_pol_1_strong
#   1000   uniform_pol_2_strong
#   1000   uniform_v_angle_1_strong
#   1000   uniform_v_angle_2_strong
#   1000   uniform_l_11_mid
#   1000   uniform_l_12_mid
#   1000   uniform_l_21_mid
#   1000   uniform_l_22_mid
#   1000   uniform_l_31_mid
#   1000   uniform_l_32_mid

# %% [markdown]
# ## Task a1: Observational data

# %% [markdown]
# #### Run GES

# %%
import ges
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import ges
#
# ModuleNotFoundError: No module named 'ges'

# %%
cpdag,_ = ges.fit_bic(observational_data, phases = ['forward', 'backward', 'turning'], debug = 0)

# %% [markdown]
# #### Estimated CPDAG

# %%
sempler.plot.plot_graph(cpdag, labels=variables)
print(graph_to_tikz(cpdag, radius=2, labels=[latex_name(v) for v in variables], bend=40, undirected="thick"))
# Out:
#     \begin{tikzpicture}
#         \node[circle, inner sep=0.12em] (0) at (-0.618, 1.902) {$R$};
#         \node[circle, inner sep=0.12em] (1) at (-1.176, 1.618) {$G$};
#         \node[circle, inner sep=0.12em] (2) at (-1.618, 1.176) {$B$};
#         \node[circle, inner sep=0.12em] (3) at (-1.902, 0.618) {$\tilde{C}$};
#         \node[circle, inner sep=0.12em] (4) at (-2.000, -0.000) {$\tilde{I}_1$};
#         \node[circle, inner sep=0.12em] (5) at (-1.902, -0.618) {$\tilde{I}_2$};
#         \node[circle, inner sep=0.12em] (6) at (-1.618, -1.176) {$\tilde{I}_3$};
#         \node[circle, inner sep=0.12em] (7) at (-1.176, -1.618) {$\tilde{V}_1$};
#         \node[circle, inner sep=0.12em] (8) at (-0.618, -1.902) {$\tilde{V}_2$};
#         \node[circle, inner sep=0.12em] (9) at (0.000, -2.000) {$\tilde{V}_3$};
#         \node[circle, inner sep=0.12em] (10) at (0.618, -1.902) {$\theta_1$};
#         \node[circle, inner sep=0.12em] (11) at (1.176, -1.618) {$\theta_2$};
#         \node[circle, inner sep=0.12em] (12) at (1.618, -1.176) {$\tilde{\theta}_1$};
#         \node[circle, inner sep=0.12em] (13) at (1.902, -0.618) {$\tilde{\theta}_2$};
#         \node[circle, inner sep=0.12em] (14) at (2.000, 0.000) {$L_{11}$};
#         \node[circle, inner sep=0.12em] (15) at (1.902, 0.618) {$L_{12}$};
#         \node[circle, inner sep=0.12em] (16) at (1.618, 1.176) {$L_{21}$};
#         \node[circle, inner sep=0.12em] (17) at (1.176, 1.618) {$L_{22}$};
#         \node[circle, inner sep=0.12em] (18) at (0.618, 1.902) {$L_{31}$};
#         \node[circle, inner sep=0.12em] (19) at (0.000, 2.000) {$L_{32}$};
#         \begin{scope}[]
#             \draw[->, bend left=28] (0) edge (3);
#             \draw[->, bend left=24] (0) edge (4);
#             \draw[->, bend left=20] (0) edge (5);
#             \draw[->, bend left=16] (0) edge (6);
#             \draw[->, bend left=12] (0) edge (7);
#             \draw[->, bend left=7] (0) edge (8);
#             \draw[->, bend left=3] (0) edge (9);
#             \draw[->, bend left=32] (1) edge (3);
#             \draw[->, bend left=28] (1) edge (4);
#             \draw[->, bend left=24] (1) edge (5);
#             \draw[->, bend left=20] (1) edge (6);
#             \draw[->, bend left=16] (1) edge (7);
#             \draw[->, bend left=12] (1) edge (8);
#             \draw[->, bend left=7] (1) edge (9);
#             \draw[->, bend left=36] (2) edge (3);
#             \draw[->, bend left=32] (2) edge (4);
#             \draw[->, bend left=28] (2) edge (5);
#             \draw[->, bend left=24] (2) edge (6);
#             \draw[->, bend left=20] (2) edge (7);
#             \draw[->, bend left=16] (2) edge (8);
#             \draw[->, bend left=12] (2) edge (9);
#             \draw[->, bend left=36] (4) edge (5);
#             \draw[-, thick, bend left=28] (4) edge (7);
#             \draw[-, thick, bend left=24] (4) edge (8);
#             \draw[->, bend right=32] (5) edge (3);
#             \draw[->, bend left=36] (5) edge (6);
#             \draw[->, bend right=28] (6) edge (3);
#             \draw[-, thick, bend right=28] (7) edge (4);
#             \draw[->, bend right=32] (7) edge (5);
#             \draw[->, bend left=32] (7) edge (9);
#             \draw[->, bend right=20] (8) edge (3);
#             \draw[-, thick, bend right=24] (8) edge (4);
#             \draw[->, bend right=28] (8) edge (5);
#             \draw[->, bend right=32] (8) edge (6);
#             \draw[->, bend left=36] (8) edge (9);
#             \draw[->, bend right=28] (9) edge (6);
#             \draw[->, bend right=24] (10) edge (6);
#             \draw[-, thick, bend left=32] (10) edge (12);
#             \draw[-, thick, bend left=32] (11) edge (13);
#             \draw[->, bend right=28] (12) edge (9);
#             \draw[-, thick, bend right=32] (12) edge (10);
#             \draw[->, bend right=12] (13) edge (6);
#             \draw[->, bend right=24] (13) edge (9);
#             \draw[-, thick, bend right=32] (13) edge (11);
#         \end{scope}
#     \end{tikzpicture}

# %% [markdown]
# #### Compute precision / recall for each DAG in the CPDAG

# %%
prec, rec = [], []
for dag in sempler.utils.all_dags(cpdag):
    prec.append(precision(dag, true_dag))
    rec.append(recall(dag, true_dag))
# Print for figure
print("precision:  ", end="")
for p in prec:
    print(("%0.2f" % p)[1:], end=" ")
print("\n   recall:  ", end="")
for r in rec:
    print(("%0.2f" % r)[1:], end=" ")
# Out:
# precision:  .60 .57 .57 .55 .60 .57 .57 .55 .60 .57 .57 .55
#    recall:  .62 .59 .59 .56 .62 .59 .59 .56 .62 .59 .59 .56

# %% [markdown]
# ## Task a2: Interventional data

# %% [markdown]
# #### Run UT-IGSP over a gridsearch of hyperparemeters
#
# - $\alpha$: significance level of cond. independence tests
# - $\beta$: significance level of invariance tests

# %%
sub_sample = 500
sub_exp = 5
interventional_data_dict = {i: dataset.get_experiment(e).as_pandas_dataframe()[variables].sample(n=sub_sample, replace=False, random_state=42).values for i,e in enumerate(experiments[:sub_exp])}

from src.causalchange.causal_change import CausalChange

# %%
import networkx as nx
print([variables[i] for i in nx.topological_sort(nx.from_numpy_array(true_dag, create_using=nx.DiGraph))])

# %%
', '.join([f'{variables[i] }->{variables[j] }' for i, j in  nx.from_numpy_array(true_dag, create_using=nx.DiGraph).edges ])
# Out:
# 'red->current, red->ir_1, red->ir_2, red->ir_3, red->vis_1, red->vis_2, red->vis_3, green->current, green->ir_1, green->ir_2, green->ir_3, green->vis_1, green->vis_2, green->vis_3, blue->current, blue->ir_1, blue->ir_2, blue->ir_3, blue->vis_1, blue->vis_2, blue->vis_3, pol_1->ir_3, pol_1->vis_3, pol_1->angle_1, pol_2->ir_3, pol_2->vis_3, pol_2->angle_2, l_11->ir_1, l_11->vis_1, l_12->ir_1, l_12->vis_1, l_21->ir_2, l_21->vis_2, l_22->ir_2, l_22->vis_2, l_31->ir_3, l_31->vis_3, l_32->ir_3, l_32->vis_3'

# %%
from src.causalchange.cc_types import DataMode, ScoreType, GraphSearch

cc = CausalChange(
    lam_mmd_hsic=1,
    data_mode=DataMode.CONTEXTS,
    score_type=ScoreType.CI.value.KCI,
    graph_search=GraphSearch.COMBO,
    node_nms=variables,
    vb=3 )
dag = cc.fit(interventional_data_dict)
# Out:
# 	*** CausalChange (data=contexts, search=GraphSearch.COMBO, s=kci) ***
# Nodes: red, green, blue, current, ir_1, ir_2, ir_3, vis_1, vis_2, vis_3, pol_1, pol_2, angle_1, angle_2, l_11, l_12, l_21, l_22, l_31, l_32
# 	Next Source (combo RESIT-ctx λ=1.00): l_11, order []
# 	best 20 next nodes:
# 	  node l_11: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0001 Dmin=-0.0001 ΔMMD=0.0000 | S=0.000
# 	  node l_21: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0001 Dmin=-0.0001 ΔMMD=0.0000 | S=0.000
# 	  node l_22: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0002 Dmin=-0.0002 ΔMMD=0.0000 | S=0.000
# 	  node l_12: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0003 Dmin=-0.0003 ΔMMD=0.0000 | S=0.000
# 	  node pol_1: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node l_32: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node pol_2: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0005 Dmin=-0.0005 ΔMMD=0.0000 | S=0.000
# 	  node l_31: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0007 Dmin=-0.0007 ΔMMD=0.0000 | S=0.000
# 	  node current: Rn_mmd=0.147 Rn_dep=0.000 D0=0.7517 Dmin=0.6411 ΔMMD=0.1106 | S=0.147
# 	  node green: Rn_mmd=0.368 Rn_dep=0.000 D0=0.5989 Dmin=0.3784 ΔMMD=0.2205 | S=0.368
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	  node angle_2: Rn_mmd=1.325 Rn_dep=0.000 D0=0.0014 Dmin=-0.0005 ΔMMD=0.0019 | S=1.325
# 	  node angle_1: Rn_mmd=2.039 Rn_dep=0.000 D0=0.0006 Dmin=-0.0007 ΔMMD=0.0013 | S=2.039
# 	1. Source: l_11	 current [14], true []
# 	Next Source (combo RESIT-ctx λ=1.00): l_21, order [14]
# 	best 19 next nodes:
# 	  node l_21: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0001 Dmin=-0.0001 ΔMMD=0.0000 | S=0.000
# 	  node l_22: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0002 Dmin=-0.0002 ΔMMD=0.0000 | S=0.000
# 	  node l_12: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0003 Dmin=-0.0003 ΔMMD=0.0000 | S=0.000
# 	  node pol_1: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node l_32: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node pol_2: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0005 Dmin=-0.0005 ΔMMD=0.0000 | S=0.000
# 	  node l_31: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0007 Dmin=-0.0007 ΔMMD=0.0000 | S=0.000
# 	  node current: Rn_mmd=0.147 Rn_dep=0.000 D0=0.7517 Dmin=0.6411 ΔMMD=0.1106 | S=0.147
# 	  node green: Rn_mmd=0.368 Rn_dep=0.000 D0=0.5989 Dmin=0.3784 ΔMMD=0.2205 | S=0.368
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	  node angle_2: Rn_mmd=1.325 Rn_dep=0.000 D0=0.0014 Dmin=-0.0005 ΔMMD=0.0019 | S=1.325
# 	  node angle_1: Rn_mmd=2.039 Rn_dep=0.000 D0=0.0006 Dmin=-0.0007 ΔMMD=0.0013 | S=2.039
# 	2. Source: l_21	 current [14, 16], true []
# 	Next Source (combo RESIT-ctx λ=1.00): l_22, order [14, 16]
# 	best 18 next nodes:
# 	  node l_22: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0002 Dmin=-0.0002 ΔMMD=0.0000 | S=0.000
# 	  node l_12: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0003 Dmin=-0.0003 ΔMMD=0.0000 | S=0.000
# 	  node pol_1: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node l_32: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node pol_2: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0005 Dmin=-0.0005 ΔMMD=0.0000 | S=0.000
# 	  node l_31: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0007 Dmin=-0.0007 ΔMMD=0.0000 | S=0.000
# 	  node current: Rn_mmd=0.147 Rn_dep=0.000 D0=0.7517 Dmin=0.6411 ΔMMD=0.1106 | S=0.147
# 	  node green: Rn_mmd=0.368 Rn_dep=0.000 D0=0.5989 Dmin=0.3784 ΔMMD=0.2205 | S=0.368
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	  node angle_2: Rn_mmd=1.325 Rn_dep=0.000 D0=0.0014 Dmin=-0.0005 ΔMMD=0.0019 | S=1.325
# 	  node angle_1: Rn_mmd=2.039 Rn_dep=0.000 D0=0.0006 Dmin=-0.0007 ΔMMD=0.0013 | S=2.039
# 	3. Source: l_22	 current [14, 16, 17], true []
# 	Next Source (combo RESIT-ctx λ=1.00): l_12, order [14, 16, 17]
# 	best 17 next nodes:
# 	  node l_12: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0003 Dmin=-0.0003 ΔMMD=0.0000 | S=0.000
# 	  node pol_1: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node l_32: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node pol_2: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0005 Dmin=-0.0005 ΔMMD=0.0000 | S=0.000
# 	  node l_31: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0007 Dmin=-0.0007 ΔMMD=0.0000 | S=0.000
# 	  node current: Rn_mmd=0.147 Rn_dep=0.000 D0=0.7517 Dmin=0.6411 ΔMMD=0.1106 | S=0.147
# 	  node green: Rn_mmd=0.368 Rn_dep=0.000 D0=0.5989 Dmin=0.3784 ΔMMD=0.2205 | S=0.368
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	  node angle_2: Rn_mmd=1.325 Rn_dep=0.000 D0=0.0014 Dmin=-0.0005 ΔMMD=0.0019 | S=1.325
# 	  node angle_1: Rn_mmd=2.039 Rn_dep=0.000 D0=0.0006 Dmin=-0.0007 ΔMMD=0.0013 | S=2.039
# 	4. Source: l_12	 current [14, 16, 17, 15], true []
# 	Next Source (combo RESIT-ctx λ=1.00): pol_1, order [14, 16, 17, 15]
# 	best 16 next nodes:
# 	  node pol_1: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node l_32: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node pol_2: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0005 Dmin=-0.0005 ΔMMD=0.0000 | S=0.000
# 	  node l_31: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0007 Dmin=-0.0007 ΔMMD=0.0000 | S=0.000
# 	  node current: Rn_mmd=0.147 Rn_dep=0.000 D0=0.7517 Dmin=0.6411 ΔMMD=0.1106 | S=0.147
# 	  node green: Rn_mmd=0.368 Rn_dep=0.000 D0=0.5989 Dmin=0.3784 ΔMMD=0.2205 | S=0.368
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	  node angle_2: Rn_mmd=1.325 Rn_dep=0.000 D0=0.0014 Dmin=-0.0005 ΔMMD=0.0019 | S=1.325
# 	  node angle_1: Rn_mmd=2.039 Rn_dep=0.000 D0=0.0006 Dmin=-0.0007 ΔMMD=0.0013 | S=2.039
# 	5. Source: pol_1	 current [14, 16, 17, 15, 10], true []
# 	Next Source (combo RESIT-ctx λ=1.00): l_32, order [14, 16, 17, 15, 10]
# 	best 15 next nodes:
# 	  node l_32: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0004 Dmin=-0.0004 ΔMMD=0.0000 | S=0.000
# 	  node pol_2: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0005 Dmin=-0.0005 ΔMMD=0.0000 | S=0.000
# 	  node l_31: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0007 Dmin=-0.0007 ΔMMD=0.0000 | S=0.000
# 	  node current: Rn_mmd=0.147 Rn_dep=0.000 D0=0.7517 Dmin=0.6411 ΔMMD=0.1106 | S=0.147
# 	  node green: Rn_mmd=0.368 Rn_dep=0.000 D0=0.5989 Dmin=0.3784 ΔMMD=0.2205 | S=0.368
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	  node angle_2: Rn_mmd=1.325 Rn_dep=0.000 D0=0.0014 Dmin=-0.0005 ΔMMD=0.0019 | S=1.325
# 	  node angle_1: Rn_mmd=2.039 Rn_dep=0.000 D0=0.0006 Dmin=-0.0007 ΔMMD=0.0013 | S=2.039
# 	6. Source: l_32	 current [14, 16, 17, 15, 10, 19], true []
# 	Next Source (combo RESIT-ctx λ=1.00): pol_2, order [14, 16, 17, 15, 10, 19]
# 	best 14 next nodes:
# 	  node pol_2: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0005 Dmin=-0.0005 ΔMMD=0.0000 | S=0.000
# 	  node l_31: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0007 Dmin=-0.0007 ΔMMD=0.0000 | S=0.000
# 	  node current: Rn_mmd=0.147 Rn_dep=0.000 D0=0.7517 Dmin=0.6411 ΔMMD=0.1106 | S=0.147
# 	  node green: Rn_mmd=0.368 Rn_dep=0.000 D0=0.5989 Dmin=0.3784 ΔMMD=0.2205 | S=0.368
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	  node angle_2: Rn_mmd=1.325 Rn_dep=0.000 D0=0.0014 Dmin=-0.0005 ΔMMD=0.0019 | S=1.325
# 	  node angle_1: Rn_mmd=2.039 Rn_dep=0.000 D0=0.0006 Dmin=-0.0007 ΔMMD=0.0013 | S=2.039
# 	7. Source: pol_2	 current [14, 16, 17, 15, 10, 19, 11], true []
# 	Next Source (combo RESIT-ctx λ=1.00): l_31, order [14, 16, 17, 15, 10, 19, 11]
# 	best 13 next nodes:
# 	  node l_31: Rn_mmd=0.000 Rn_dep=0.000 D0=-0.0007 Dmin=-0.0007 ΔMMD=0.0000 | S=0.000
# 	  node current: Rn_mmd=0.147 Rn_dep=0.000 D0=0.7517 Dmin=0.6411 ΔMMD=0.1106 | S=0.147
# 	  node green: Rn_mmd=0.368 Rn_dep=0.000 D0=0.5989 Dmin=0.3784 ΔMMD=0.2205 | S=0.368
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	  node angle_2: Rn_mmd=1.325 Rn_dep=0.000 D0=0.0014 Dmin=-0.0005 ΔMMD=0.0019 | S=1.325
# 	  node angle_1: Rn_mmd=2.039 Rn_dep=0.000 D0=0.0006 Dmin=-0.0007 ΔMMD=0.0013 | S=2.039
# 	8. Source: l_31	 current [14, 16, 17, 15, 10, 19, 11, 18], true []
# 	Next Source (combo RESIT-ctx λ=1.00): current, order [14, 16, 17, 15, 10, 19, 11, 18]
# 	best 12 next nodes:
# 	  node current: Rn_mmd=0.147 Rn_dep=0.000 D0=0.7517 Dmin=0.6411 ΔMMD=0.1106 | S=0.147
# 	  node green: Rn_mmd=0.368 Rn_dep=0.000 D0=0.5989 Dmin=0.3784 ΔMMD=0.2205 | S=0.368
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	  node angle_2: Rn_mmd=1.325 Rn_dep=0.000 D0=0.0014 Dmin=-0.0005 ΔMMD=0.0019 | S=1.325
# 	  node angle_1: Rn_mmd=2.039 Rn_dep=0.000 D0=0.0006 Dmin=-0.0007 ΔMMD=0.0013 | S=2.039
# 	9. Source: current	 current [14, 16, 17, 15, 10, 19, 11, 18, 3], true []
# 	Next Source (combo RESIT-ctx λ=1.00): green, order [14, 16, 17, 15, 10, 19, 11, 18, 3]
# 	best 11 next nodes:
# 	  node green: Rn_mmd=0.368 Rn_dep=0.000 D0=0.5989 Dmin=0.3784 ΔMMD=0.2205 | S=0.368
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node angle_1: Rn_mmd=0.713 Rn_dep=0.000 D0=0.0006 Dmin=0.0002 ΔMMD=0.0005 | S=0.713
# 	  node angle_2: Rn_mmd=0.724 Rn_dep=0.000 D0=0.0014 Dmin=0.0004 ΔMMD=0.0010 | S=0.724
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	10. Source: green	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1], true []
# 	Next Source (combo RESIT-ctx λ=1.00): angle_2, order [14, 16, 17, 15, 10, 19, 11, 18, 3, 1]
# 	best 10 next nodes:
# 	  node angle_2: Rn_mmd=0.603 Rn_dep=0.000 D0=0.0014 Dmin=0.0006 ΔMMD=0.0009 | S=0.603
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node angle_1: Rn_mmd=0.713 Rn_dep=0.000 D0=0.0006 Dmin=0.0002 ΔMMD=0.0005 | S=0.713
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	11. Source: angle_2	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13], true []
# 	Next Source (combo RESIT-ctx λ=1.00): red, order [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13]
# 	best 9 next nodes:
# 	  node red: Rn_mmd=0.640 Rn_dep=0.000 D0=0.6028 Dmin=0.2167 ΔMMD=0.3861 | S=0.640
# 	  node angle_1: Rn_mmd=0.713 Rn_dep=0.000 D0=0.0006 Dmin=0.0002 ΔMMD=0.0005 | S=0.713
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	12. Source: red	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0], true []
# 	Next Source (combo RESIT-ctx λ=1.00): angle_1, order [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0]
# 	best 8 next nodes:
# 	  node angle_1: Rn_mmd=0.713 Rn_dep=0.000 D0=0.0006 Dmin=0.0002 ΔMMD=0.0005 | S=0.713
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	13. Source: angle_1	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12], true []
# 	Next Source (combo RESIT-ctx λ=1.00): blue, order [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12]
# 	best 7 next nodes:
# 	  node blue: Rn_mmd=0.741 Rn_dep=0.000 D0=0.6035 Dmin=0.1563 ΔMMD=0.4471 | S=0.741
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	14. Source: blue	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2], true []
# 	Next Source (combo RESIT-ctx λ=1.00): ir_3, order [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2]
# 	best 6 next nodes:
# 	  node ir_3: Rn_mmd=0.944 Rn_dep=0.000 D0=0.6670 Dmin=0.0377 ΔMMD=0.6293 | S=0.944
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node ir_2: Rn_mmd=0.953 Rn_dep=0.000 D0=0.7092 Dmin=0.0331 ΔMMD=0.6761 | S=0.953
# 	  node ir_1: Rn_mmd=0.955 Rn_dep=0.000 D0=0.7171 Dmin=0.0324 ΔMMD=0.6848 | S=0.955
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	15. Source: ir_3	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6], true []
# 	Next Source (combo RESIT-ctx λ=1.00): ir_2, order [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6]
# 	best 5 next nodes:
# 	  node ir_2: Rn_mmd=0.896 Rn_dep=0.000 D0=0.7092 Dmin=0.0737 ΔMMD=0.6355 | S=0.896
# 	  node ir_1: Rn_mmd=0.904 Rn_dep=0.000 D0=0.7171 Dmin=0.0688 ΔMMD=0.6483 | S=0.904
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	16. Source: ir_2	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5], true []
# 	Next Source (combo RESIT-ctx λ=1.00): ir_1, order [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5]
# 	best 4 next nodes:
# 	  node ir_1: Rn_mmd=0.509 Rn_dep=0.000 D0=0.7171 Dmin=0.3518 ΔMMD=0.3653 | S=0.509
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	17. Source: ir_1	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4], true []
# 	Next Source (combo RESIT-ctx λ=1.00): vis_3, order [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4]
# 	best 3 next nodes:
# 	  node vis_3: Rn_mmd=0.945 Rn_dep=0.000 D0=0.6980 Dmin=0.0383 ΔMMD=0.6597 | S=0.945
# 	  node vis_2: Rn_mmd=0.962 Rn_dep=0.000 D0=0.7383 Dmin=0.0280 ΔMMD=0.7103 | S=0.962
# 	  node vis_1: Rn_mmd=0.983 Rn_dep=0.000 D0=0.7406 Dmin=0.0123 ΔMMD=0.7283 | S=0.983
# 	18. Source: vis_3	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9], true []
# 	Next Source (combo RESIT-ctx λ=1.00): vis_2, order [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9]
# 	best 2 next nodes:
# 	  node vis_2: Rn_mmd=0.954 Rn_dep=0.000 D0=0.7383 Dmin=0.0338 ΔMMD=0.7044 | S=0.954
# 	  node vis_1: Rn_mmd=0.954 Rn_dep=0.000 D0=0.7406 Dmin=0.0337 ΔMMD=0.7068 | S=0.954
# 	19. Source: vis_2	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8], true []
# 	Next Source (combo RESIT-ctx λ=1.00): vis_1, order [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8]
# 	best 1 next nodes:
# 	  node vis_1: Rn_mmd=0.000 Rn_dep=0.000 D0=0.7406 Dmin=0.7406 ΔMMD=0.0000 | S=0.000
# 	20. Source: vis_1	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7], true []
# 	[edges] using gain_min≈0.045 from n_eff=500
# 	  no incoming edges added to l_11 (gain_min=0.045)
# 	  +edge l_11->l_21 () (gain=0.675, r_mmd=0.000, r_hsic=0.293, D_base=-0.0001, D_with=-0.0001)
# 	  +edge l_11->l_22 () (gain=0.791, r_mmd=0.000, r_hsic=0.172, D_base=-0.0002, D_with=-0.0002)
# 	  +edge l_21->l_22 () (gain=0.576, r_mmd=0.000, r_hsic=0.397, D_base=-0.0002, D_with=-0.0002)
# 	  +edge l_22->l_12 () (gain=0.868, r_mmd=0.000, r_hsic=0.091, D_base=-0.0003, D_with=-0.0003)
# 	  +edge l_11->l_12 () (gain=0.611, r_mmd=0.000, r_hsic=0.360, D_base=-0.0003, D_with=-0.0003)
# 	  +edge l_21->l_12 () (gain=0.475, r_mmd=0.000, r_hsic=0.503, D_base=-0.0003, D_with=-0.0003)
# 	  +edge l_21->pol_1 () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=-0.0004, D_with=-0.0004)
# 	  +edge l_12->pol_1 () (gain=0.736, r_mmd=0.000, r_hsic=0.229, D_base=-0.0004, D_with=-0.0004)
# 	  +edge l_22->pol_1 () (gain=0.663, r_mmd=0.000, r_hsic=0.306, D_base=-0.0004, D_with=-0.0004)
# 	  +edge l_11->pol_1 () (gain=0.379, r_mmd=0.000, r_hsic=0.604, D_base=-0.0004, D_with=-0.0004)
# 	  +edge l_22->l_32 () (gain=0.861, r_mmd=0.000, r_hsic=0.099, D_base=-0.0004, D_with=-0.0004)
# 	  +edge l_11->l_32 () (gain=0.839, r_mmd=0.000, r_hsic=0.121, D_base=-0.0004, D_with=-0.0004)
# 	  +edge l_12->l_32 () (gain=0.823, r_mmd=0.000, r_hsic=0.139, D_base=-0.0004, D_with=-0.0004)
# 	  +edge pol_1->l_32 () (gain=0.718, r_mmd=0.000, r_hsic=0.249, D_base=-0.0004, D_with=-0.0004)
# 	  +edge l_21->l_32 () (gain=0.627, r_mmd=0.000, r_hsic=0.344, D_base=-0.0004, D_with=-0.0004)
# 	  +edge l_22->pol_2 () (gain=0.898, r_mmd=0.000, r_hsic=0.060, D_base=-0.0005, D_with=-0.0005)
# 	  +edge l_11->pol_2 () (gain=0.895, r_mmd=0.000, r_hsic=0.063, D_base=-0.0005, D_with=-0.0005)
# 	  +edge l_32->pol_2 () (gain=0.795, r_mmd=0.000, r_hsic=0.167, D_base=-0.0005, D_with=-0.0005)
# 	  +edge l_12->pol_2 () (gain=0.719, r_mmd=0.000, r_hsic=0.247, D_base=-0.0005, D_with=-0.0005)
# 	  +edge pol_1->pol_2 () (gain=0.615, r_mmd=0.000, r_hsic=0.356, D_base=-0.0005, D_with=-0.0005)
# 	  +edge l_21->pol_2 () (gain=0.386, r_mmd=0.000, r_hsic=0.596, D_base=-0.0005, D_with=-0.0005)
# 	  +edge pol_1->l_31 () (gain=0.867, r_mmd=0.000, r_hsic=0.093, D_base=-0.0007, D_with=-0.0007)
# 	  +edge l_21->l_31 () (gain=0.864, r_mmd=0.000, r_hsic=0.096, D_base=-0.0007, D_with=-0.0007)
# 	  +edge l_12->l_31 () (gain=0.859, r_mmd=0.000, r_hsic=0.101, D_base=-0.0007, D_with=-0.0007)
# 	  +edge l_11->l_31 () (gain=0.792, r_mmd=0.000, r_hsic=0.171, D_base=-0.0007, D_with=-0.0007)
# 	  +edge pol_2->l_31 () (gain=0.776, r_mmd=0.000, r_hsic=0.188, D_base=-0.0007, D_with=-0.0007)
# 	  +edge l_32->l_31 () (gain=0.732, r_mmd=0.000, r_hsic=0.234, D_base=-0.0007, D_with=-0.0007)
# 	  +edge l_22->l_31 () (gain=0.706, r_mmd=0.000, r_hsic=0.260, D_base=-0.0007, D_with=-0.0007)
# 	  +edge l_11->current () (gain=0.959, r_mmd=0.075, r_hsic=0.000, D_base=0.7517, D_with=0.6957)
# 	  +edge pol_2->current () (gain=0.958, r_mmd=0.061, r_hsic=0.000, D_base=0.7517, D_with=0.7060)
# 	  +edge pol_1->current () (gain=0.957, r_mmd=0.044, r_hsic=0.000, D_base=0.7517, D_with=0.7185)
# 	  +edge l_12->current () (gain=0.957, r_mmd=0.042, r_hsic=0.000, D_base=0.7517, D_with=0.7201)
# 	  +edge l_21->current () (gain=0.957, r_mmd=0.038, r_hsic=0.000, D_base=0.7517, D_with=0.7232)
# 	  +edge l_32->current () (gain=0.957, r_mmd=0.036, r_hsic=0.000, D_base=0.7517, D_with=0.7245)
# 	  +edge l_31->current () (gain=0.957, r_mmd=0.034, r_hsic=0.000, D_base=0.7517, D_with=0.7265)
# 	  +edge l_22->current () (gain=0.956, r_mmd=0.006, r_hsic=0.000, D_base=0.7517, D_with=0.7470)
# 	  +edge l_12->green () (gain=0.956, r_mmd=0.006, r_hsic=0.000, D_base=0.5989, D_with=0.5953)
# 	  +edge pol_1->green () (gain=0.955, r_mmd=0.004, r_hsic=0.000, D_base=0.5989, D_with=0.5964)
# 	  +edge l_21->green () (gain=0.955, r_mmd=0.004, r_hsic=0.000, D_base=0.5989, D_with=0.5967)
# 	  +edge pol_2->green () (gain=0.955, r_mmd=0.003, r_hsic=0.000, D_base=0.5989, D_with=0.5969)
# 	  +edge l_31->green () (gain=0.955, r_mmd=0.003, r_hsic=0.000, D_base=0.5989, D_with=0.5969)
# 	  +edge l_11->green () (gain=0.955, r_mmd=0.002, r_hsic=0.000, D_base=0.5989, D_with=0.5980)
# 	  +edge l_22->green () (gain=0.955, r_mmd=0.001, r_hsic=0.000, D_base=0.5989, D_with=0.5981)
# 	  +edge l_32->green () (gain=0.955, r_mmd=0.001, r_hsic=0.000, D_base=0.5989, D_with=0.5982)
# 	  +edge current->green () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.5989, D_with=0.8211)
# 	  +edge l_11->angle_2 () (gain=0.931, r_mmd=0.000, r_hsic=0.026, D_base=0.0014, D_with=0.0015)
# 	  +edge l_22->angle_2 () (gain=0.905, r_mmd=0.000, r_hsic=0.053, D_base=0.0014, D_with=0.0014)
# 	  +edge l_32->angle_2 () (gain=0.799, r_mmd=0.000, r_hsic=0.164, D_base=0.0014, D_with=0.0015)
# 	  +edge l_12->angle_2 () (gain=0.751, r_mmd=0.029, r_hsic=0.215, D_base=0.0014, D_with=0.0014)
# 	  +edge pol_1->angle_2 () (gain=0.602, r_mmd=0.109, r_hsic=0.375, D_base=0.0014, D_with=0.0013)
# 	  +edge l_31->angle_2 () (gain=0.515, r_mmd=0.000, r_hsic=0.461, D_base=0.0014, D_with=0.0015)
# 	  +edge l_21->angle_2 () (gain=0.397, r_mmd=0.000, r_hsic=0.584, D_base=0.0014, D_with=0.0015)
# 	  +edge green->angle_2 () (gain=0.388, r_mmd=0.724, r_hsic=0.628, D_base=0.0014, D_with=0.0004)
# 	  +edge current->angle_2 () (gain=0.267, r_mmd=1.325, r_hsic=0.783, D_base=0.0014, D_with=-0.0005)
# 	  +edge l_12->red () (gain=0.956, r_mmd=0.007, r_hsic=0.000, D_base=0.6028, D_with=0.5985)
# 	  +edge pol_1->red () (gain=0.955, r_mmd=0.004, r_hsic=0.000, D_base=0.6028, D_with=0.6004)
# 	  +edge l_11->red () (gain=0.955, r_mmd=0.004, r_hsic=0.000, D_base=0.6028, D_with=0.6005)
# 	  +edge l_21->red () (gain=0.955, r_mmd=0.003, r_hsic=0.000, D_base=0.6028, D_with=0.6012)
# 	  +edge l_22->red () (gain=0.955, r_mmd=0.003, r_hsic=0.000, D_base=0.6028, D_with=0.6012)
# 	  +edge l_32->red () (gain=0.955, r_mmd=0.002, r_hsic=0.000, D_base=0.6028, D_with=0.6018)
# 	  +edge l_31->red () (gain=0.955, r_mmd=0.001, r_hsic=0.000, D_base=0.6028, D_with=0.6021)
# 	  +edge angle_2->red () (gain=0.955, r_mmd=0.001, r_hsic=0.000, D_base=0.6028, D_with=0.6022)
# 	  +edge pol_2->red () (gain=0.955, r_mmd=0.001, r_hsic=0.000, D_base=0.6028, D_with=0.6023)
# 	  +edge current->red () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.6028, D_with=0.8169)
# 	  +edge green->red () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.6028, D_with=0.7234)
# 	  +edge l_21->angle_1 () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.0006, D_with=0.0008)
# 	  +edge red->angle_1 () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.0006, D_with=0.0007)
# 	  +edge l_12->angle_1 () (gain=0.804, r_mmd=0.143, r_hsic=0.165, D_base=0.0006, D_with=0.0005)
# 	  +edge green->angle_1 () (gain=0.746, r_mmd=0.263, r_hsic=0.232, D_base=0.0006, D_with=0.0005)
# 	  +edge l_31->angle_1 () (gain=0.737, r_mmd=0.000, r_hsic=0.229, D_base=0.0006, D_with=0.0007)
# 	  +edge l_22->angle_1 () (gain=0.722, r_mmd=0.006, r_hsic=0.244, D_base=0.0006, D_with=0.0006)
# 	  +edge current->angle_1 () (gain=0.677, r_mmd=2.039, r_hsic=0.387, D_base=0.0006, D_with=-0.0007)
# 	  +edge pol_2->angle_1 () (gain=0.640, r_mmd=0.000, r_hsic=0.330, D_base=0.0006, D_with=0.0006)
# 	  +edge angle_2->angle_1 () (gain=0.617, r_mmd=0.006, r_hsic=0.354, D_base=0.0006, D_with=0.0006)
# 	  +edge l_32->angle_1 () (gain=0.579, r_mmd=0.000, r_hsic=0.394, D_base=0.0006, D_with=0.0007)
# 	  +edge l_11->angle_1 () (gain=0.386, r_mmd=0.000, r_hsic=0.596, D_base=0.0006, D_with=0.0007)
# 	  +edge l_22->blue () (gain=0.956, r_mmd=0.009, r_hsic=0.000, D_base=0.6035, D_with=0.5979)
# 	  +edge angle_1->blue () (gain=0.956, r_mmd=0.008, r_hsic=0.000, D_base=0.6035, D_with=0.5988)
# 	  +edge l_21->blue () (gain=0.956, r_mmd=0.008, r_hsic=0.000, D_base=0.6035, D_with=0.5989)
# 	  +edge angle_2->blue () (gain=0.956, r_mmd=0.007, r_hsic=0.000, D_base=0.6035, D_with=0.5993)
# 	  +edge l_12->blue () (gain=0.956, r_mmd=0.007, r_hsic=0.000, D_base=0.6035, D_with=0.5993)
# 	  +edge pol_2->blue () (gain=0.956, r_mmd=0.007, r_hsic=0.000, D_base=0.6035, D_with=0.5994)
# 	  +edge pol_1->blue () (gain=0.956, r_mmd=0.007, r_hsic=0.000, D_base=0.6035, D_with=0.5994)
# 	  +edge l_11->blue () (gain=0.956, r_mmd=0.006, r_hsic=0.000, D_base=0.6035, D_with=0.5996)
# 	  +edge current->blue () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.6035, D_with=0.8276)
# 	  +edge green->blue () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.6035, D_with=0.7227)
# 	  +edge red->blue () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.6035, D_with=0.7252)
# 	  +edge l_31->blue () (gain=0.800, r_mmd=0.007, r_hsic=0.162, D_base=0.6035, D_with=0.5990)
# 	  +edge l_32->blue () (gain=0.778, r_mmd=0.007, r_hsic=0.186, D_base=0.6035, D_with=0.5994)
# 	  +edge blue->ir_3 () (gain=0.944, r_mmd=0.000, r_hsic=0.012, D_base=0.6670, D_with=0.6939)
# 	  +edge l_31->ir_3 () (gain=0.773, r_mmd=0.001, r_hsic=0.191, D_base=0.6670, D_with=0.6662)
# 	  +edge l_21->ir_3 () (gain=0.679, r_mmd=0.002, r_hsic=0.289, D_base=0.6670, D_with=0.6654)
# 	  +edge l_11->ir_3 () (gain=0.674, r_mmd=0.006, r_hsic=0.294, D_base=0.6670, D_with=0.6631)
# 	  +edge l_22->ir_3 () (gain=0.632, r_mmd=0.004, r_hsic=0.339, D_base=0.6670, D_with=0.6646)
# 	  +edge l_32->ir_3 () (gain=0.509, r_mmd=0.007, r_hsic=0.467, D_base=0.6670, D_with=0.6625)
# 	  +edge pol_1->ir_3 () (gain=0.508, r_mmd=0.000, r_hsic=0.469, D_base=0.6670, D_with=0.6684)
# 	  +edge angle_1->ir_3 () (gain=0.501, r_mmd=0.005, r_hsic=0.476, D_base=0.6670, D_with=0.6639)
# 	  +edge l_12->ir_3 () (gain=0.478, r_mmd=0.008, r_hsic=0.500, D_base=0.6670, D_with=0.6615)
# 	  +edge green->ir_3 () (gain=0.476, r_mmd=0.000, r_hsic=0.502, D_base=0.6670, D_with=0.6865)
# 	  +edge angle_2->ir_3 () (gain=0.470, r_mmd=0.006, r_hsic=0.508, D_base=0.6670, D_with=0.6631)
# 	  +edge pol_2->ir_3 () (gain=0.465, r_mmd=0.000, r_hsic=0.513, D_base=0.6670, D_with=0.6707)
# 	  +edge red->ir_3 () (gain=0.130, r_mmd=0.066, r_hsic=0.867, D_base=0.6670, D_with=0.6226)
# 	  +edge current->ir_3 () (gain=0.113, r_mmd=0.478, r_hsic=0.904, D_base=0.6670, D_with=0.3479)
# 	  +edge blue->ir_2 () (gain=0.945, r_mmd=0.000, r_hsic=0.010, D_base=0.7092, D_with=0.7410)
# 	  +edge angle_1->ir_2 () (gain=0.801, r_mmd=0.009, r_hsic=0.162, D_base=0.7092, D_with=0.7026)
# 	  +edge l_31->ir_2 () (gain=0.784, r_mmd=0.002, r_hsic=0.180, D_base=0.7092, D_with=0.7080)
# 	  +edge pol_2->ir_2 () (gain=0.774, r_mmd=0.001, r_hsic=0.189, D_base=0.7092, D_with=0.7087)
# 	  +edge l_22->ir_2 () (gain=0.682, r_mmd=0.005, r_hsic=0.286, D_base=0.7092, D_with=0.7058)
# 	  +edge l_21->ir_2 () (gain=0.679, r_mmd=0.003, r_hsic=0.289, D_base=0.7092, D_with=0.7071)
# 	  +edge l_11->ir_2 () (gain=0.675, r_mmd=0.006, r_hsic=0.293, D_base=0.7092, D_with=0.7052)
# 	  +edge pol_1->ir_2 () (gain=0.655, r_mmd=0.004, r_hsic=0.314, D_base=0.7092, D_with=0.7066)
# 	  +edge angle_2->ir_2 () (gain=0.614, r_mmd=0.012, r_hsic=0.357, D_base=0.7092, D_with=0.7009)
# 	  +edge green->ir_2 () (gain=0.574, r_mmd=0.000, r_hsic=0.399, D_base=0.7092, D_with=0.7390)
# 	  +edge l_12->ir_2 () (gain=0.561, r_mmd=0.009, r_hsic=0.413, D_base=0.7092, D_with=0.7028)
# 	  +edge l_32->ir_2 () (gain=0.485, r_mmd=0.006, r_hsic=0.493, D_base=0.7092, D_with=0.7051)
# 	  +edge red->ir_2 () (gain=0.189, r_mmd=0.003, r_hsic=0.802, D_base=0.7092, D_with=0.7073)
# 	  +edge current->ir_2 () (gain=0.115, r_mmd=0.374, r_hsic=0.897, D_base=0.7092, D_with=0.4441)
# 	  +edge ir_3->ir_2 () (gain=0.068, r_mmd=0.953, r_hsic=0.973, D_base=0.7092, D_with=0.0331)
# 	  +edge blue->ir_1 () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.7171, D_with=0.7441)
# 	  +edge pol_2->ir_1 () (gain=0.855, r_mmd=0.001, r_hsic=0.105, D_base=0.7171, D_with=0.7165)
# 	  +edge angle_1->ir_1 () (gain=0.806, r_mmd=0.008, r_hsic=0.157, D_base=0.7171, D_with=0.7111)
# 	  +edge l_31->ir_1 () (gain=0.733, r_mmd=0.001, r_hsic=0.232, D_base=0.7171, D_with=0.7163)
# 	  +edge l_11->ir_1 () (gain=0.687, r_mmd=0.006, r_hsic=0.281, D_base=0.7171, D_with=0.7132)
# 	  +edge angle_2->ir_1 () (gain=0.667, r_mmd=0.014, r_hsic=0.302, D_base=0.7171, D_with=0.7075)
# 	  +edge pol_1->ir_1 () (gain=0.664, r_mmd=0.004, r_hsic=0.305, D_base=0.7171, D_with=0.7145)
# 	  +edge l_21->ir_1 () (gain=0.655, r_mmd=0.003, r_hsic=0.314, D_base=0.7171, D_with=0.7152)
# 	  +edge l_22->ir_1 () (gain=0.619, r_mmd=0.004, r_hsic=0.352, D_base=0.7171, D_with=0.7142)
# 	  +edge l_12->ir_1 () (gain=0.553, r_mmd=0.009, r_hsic=0.422, D_base=0.7171, D_with=0.7107)
# 	  +edge green->ir_1 () (gain=0.510, r_mmd=0.000, r_hsic=0.466, D_base=0.7171, D_with=0.7414)
# 	  +edge l_32->ir_1 () (gain=0.473, r_mmd=0.006, r_hsic=0.505, D_base=0.7171, D_with=0.7131)
# 	  +edge red->ir_1 () (gain=0.181, r_mmd=0.000, r_hsic=0.810, D_base=0.7171, D_with=0.7188)
# 	  +edge current->ir_1 () (gain=0.127, r_mmd=0.337, r_hsic=0.883, D_base=0.7171, D_with=0.4757)
# 	  +edge ir_3->ir_1 () (gain=0.071, r_mmd=0.955, r_hsic=0.970, D_base=0.7171, D_with=0.0324)
# 	  +edge ir_2->ir_1 () (gain=0.053, r_mmd=0.904, r_hsic=0.987, D_base=0.7171, D_with=0.0688)
# 	  +edge l_21->vis_3 () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.6980, D_with=0.6980)
# 	  +edge red->vis_3 () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.6980, D_with=0.7065)
# 	  +edge l_12->vis_3 () (gain=0.926, r_mmd=0.001, r_hsic=0.031, D_base=0.6980, D_with=0.6975)
# 	  +edge l_22->vis_3 () (gain=0.857, r_mmd=0.000, r_hsic=0.103, D_base=0.6980, D_with=0.6979)
# 	  +edge l_31->vis_3 () (gain=0.841, r_mmd=0.000, r_hsic=0.120, D_base=0.6980, D_with=0.6980)
# 	  +edge l_11->vis_3 () (gain=0.749, r_mmd=0.006, r_hsic=0.216, D_base=0.6980, D_with=0.6939)
# 	  +edge l_32->vis_3 () (gain=0.721, r_mmd=0.005, r_hsic=0.246, D_base=0.6980, D_with=0.6941)
# 	  +edge angle_2->vis_3 () (gain=0.576, r_mmd=0.007, r_hsic=0.397, D_base=0.6980, D_with=0.6931)
# 	  +edge pol_1->vis_3 () (gain=0.562, r_mmd=0.000, r_hsic=0.411, D_base=0.6980, D_with=0.7022)
# 	  +edge angle_1->vis_3 () (gain=0.547, r_mmd=0.010, r_hsic=0.428, D_base=0.6980, D_with=0.6910)
# 	  +edge pol_2->vis_3 () (gain=0.515, r_mmd=0.000, r_hsic=0.461, D_base=0.6980, D_with=0.7002)
# 	  +edge green->vis_3 () (gain=0.505, r_mmd=0.001, r_hsic=0.472, D_base=0.6980, D_with=0.6973)
# 	  +edge ir_3->vis_3 () (gain=0.264, r_mmd=0.451, r_hsic=0.745, D_base=0.6980, D_with=0.3833)
# 	  +edge current->vis_3 () (gain=0.251, r_mmd=0.216, r_hsic=0.747, D_base=0.6980, D_with=0.5472)
# 	  +edge ir_2->vis_3 () (gain=0.242, r_mmd=0.550, r_hsic=0.773, D_base=0.6980, D_with=0.3141)
# 	  +edge ir_1->vis_3 () (gain=0.220, r_mmd=0.559, r_hsic=0.795, D_base=0.6980, D_with=0.3076)
# 	  +edge blue->vis_3 () (gain=0.085, r_mmd=0.129, r_hsic=0.917, D_base=0.6980, D_with=0.6078)
# 	  +edge pol_2->vis_2 () (gain=0.955, r_mmd=0.003, r_hsic=0.000, D_base=0.7383, D_with=0.7363)
# 	  +edge l_21->vis_2 () (gain=0.955, r_mmd=0.001, r_hsic=0.000, D_base=0.7383, D_with=0.7372)
# 	  +edge red->vis_2 () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.7383, D_with=0.7462)
# 	  +edge pol_1->vis_2 () (gain=0.921, r_mmd=0.000, r_hsic=0.036, D_base=0.7383, D_with=0.7379)
# 	  +edge angle_1->vis_2 () (gain=0.912, r_mmd=0.016, r_hsic=0.046, D_base=0.7383, D_with=0.7266)
# 	  +edge l_22->vis_2 () (gain=0.886, r_mmd=0.002, r_hsic=0.073, D_base=0.7383, D_with=0.7366)
# 	  +edge l_31->vis_2 () (gain=0.863, r_mmd=0.003, r_hsic=0.097, D_base=0.7383, D_with=0.7362)
# 	  +edge l_12->vis_2 () (gain=0.855, r_mmd=0.002, r_hsic=0.105, D_base=0.7383, D_with=0.7371)
# 	  +edge l_11->vis_2 () (gain=0.828, r_mmd=0.008, r_hsic=0.134, D_base=0.7383, D_with=0.7326)
# 	  +edge angle_2->vis_2 () (gain=0.736, r_mmd=0.013, r_hsic=0.230, D_base=0.7383, D_with=0.7288)
# 	  +edge l_32->vis_2 () (gain=0.659, r_mmd=0.006, r_hsic=0.310, D_base=0.7383, D_with=0.7335)
# 	  +edge green->vis_2 () (gain=0.589, r_mmd=0.000, r_hsic=0.384, D_base=0.7383, D_with=0.7448)
# 	  +edge current->vis_2 () (gain=0.300, r_mmd=0.144, r_hsic=0.693, D_base=0.7383, D_with=0.6322)
# 	  +edge ir_2->vis_2 () (gain=0.269, r_mmd=0.500, r_hsic=0.742, D_base=0.7383, D_with=0.3689)
# 	  +edge ir_3->vis_2 () (gain=0.238, r_mmd=0.503, r_hsic=0.774, D_base=0.7383, D_with=0.3671)
# 	  +edge ir_1->vis_2 () (gain=0.237, r_mmd=0.528, r_hsic=0.776, D_base=0.7383, D_with=0.3481)
# 	  +edge blue->vis_2 () (gain=0.132, r_mmd=0.035, r_hsic=0.864, D_base=0.7383, D_with=0.7126)
# 	  +edge vis_3->vis_2 () (gain=0.078, r_mmd=0.962, r_hsic=0.964, D_base=0.7383, D_with=0.0280)
# 	  +edge pol_2->vis_1 () (gain=0.955, r_mmd=0.003, r_hsic=0.000, D_base=0.7406, D_with=0.7384)
# 	  +edge red->vis_1 () (gain=0.955, r_mmd=0.000, r_hsic=0.000, D_base=0.7406, D_with=0.7502)
# 	  +edge l_12->vis_1 () (gain=0.919, r_mmd=0.002, r_hsic=0.038, D_base=0.7406, D_with=0.7390)
# 	  +edge l_22->vis_1 () (gain=0.891, r_mmd=0.002, r_hsic=0.068, D_base=0.7406, D_with=0.7392)
# 	  +edge pol_1->vis_1 () (gain=0.890, r_mmd=0.002, r_hsic=0.068, D_base=0.7406, D_with=0.7394)
# 	  +edge l_21->vis_1 () (gain=0.888, r_mmd=0.001, r_hsic=0.070, D_base=0.7406, D_with=0.7395)
# 	  +edge l_31->vis_1 () (gain=0.831, r_mmd=0.002, r_hsic=0.131, D_base=0.7406, D_with=0.7390)
# 	  +edge angle_1->vis_1 () (gain=0.816, r_mmd=0.016, r_hsic=0.146, D_base=0.7406, D_with=0.7287)
# 	  +edge angle_2->vis_1 () (gain=0.805, r_mmd=0.014, r_hsic=0.158, D_base=0.7406, D_with=0.7299)
# 	  +edge l_11->vis_1 () (gain=0.777, r_mmd=0.008, r_hsic=0.187, D_base=0.7406, D_with=0.7347)
# 	  +edge l_32->vis_1 () (gain=0.661, r_mmd=0.007, r_hsic=0.309, D_base=0.7406, D_with=0.7352)
# 	  +edge green->vis_1 () (gain=0.523, r_mmd=0.000, r_hsic=0.452, D_base=0.7406, D_with=0.7497)
# 	  +edge current->vis_1 () (gain=0.232, r_mmd=0.181, r_hsic=0.765, D_base=0.7406, D_with=0.6062)
# 	  +edge ir_2->vis_1 () (gain=0.226, r_mmd=0.546, r_hsic=0.789, D_base=0.7406, D_with=0.3364)
# 	  +edge ir_1->vis_1 () (gain=0.214, r_mmd=0.548, r_hsic=0.801, D_base=0.7406, D_with=0.3344)
# 	  +edge ir_3->vis_1 () (gain=0.212, r_mmd=0.525, r_hsic=0.803, D_base=0.7406, D_with=0.3518)
# 	  +edge blue->vis_1 () (gain=0.149, r_mmd=0.026, r_hsic=0.845, D_base=0.7406, D_with=0.7212)
# 	  +edge vis_3->vis_1 () (gain=0.067, r_mmd=0.983, r_hsic=0.975, D_base=0.7406, D_with=0.0123)
# 	  +edge vis_2->vis_1 () (gain=0.055, r_mmd=0.954, r_hsic=0.987, D_base=0.7406, D_with=0.0337)
# 	[prune] using prune_min≈0.022
# 	[prune] no edges pruned

# %%
est_dag_nx = dag
dg = nx.to_numpy_array(dag)
true_nx = nx.from_numpy_array(true_dag, create_using=nx.DiGraph)
print(precision(dg, true_dag))
print(f'Precision: {precision(dg, true_dag)}')
print(f'Recall: {recall(dg, true_dag)}')
print(f'True Order : {[i for i in nx.topological_sort(nx.from_numpy_array(true_dag, create_using=nx.DiGraph))]}')
print(f'Est Order : {[i for i in nx.topological_sort(dag)]}')
est_order =  [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
for i in nx.topological_sort(dag):
    print(f'{variables[i]}: pre={len(list(true_nx.predecessors(i)))}, succ={len(list(true_nx.successors(i)))}')
# Out:
# 0.32857142857142857
# Precision: 0.32857142857142857
# Recall: 0.5897435897435898
# True Order : [0, 1, 2, 10, 11, 14, 15, 16, 17, 18, 19, 3, 12, 13, 4, 7, 5, 8, 6, 9]
# Est Order : [0, 10, 11, 14, 15, 16, 17, 18, 19, 1, 2, 3, 4, 5, 6, 7, 8, 9, 12, 13]
# red: pre=0, succ=7
# pol_1: pre=0, succ=3
# pol_2: pre=0, succ=3
# l_11: pre=0, succ=2
# l_12: pre=0, succ=2
# l_21: pre=0, succ=2
# l_22: pre=0, succ=2
# l_31: pre=0, succ=2
# l_32: pre=0, succ=2
# green: pre=0, succ=7
# blue: pre=0, succ=7
# current: pre=3, succ=0
# ir_1: pre=5, succ=0
# ir_2: pre=5, succ=0
# ir_3: pre=7, succ=0
# vis_1: pre=5, succ=0
# vis_2: pre=5, succ=0
# vis_3: pre=7, succ=0
# angle_1: pre=1, succ=0
# angle_2: pre=1, succ=0

# %%
cc = CausalChange(
    lam_mmd_hsic=1,
    data_mode=DataMode.CONTEXTS,
    score_type=ScoreType.CI.value.KCI,
    graph_search=GraphSearch.COMBO,
    node_nms=variables,
    oracle_order=True,
    truths={'true_g': true_nx, # est_dag_nx,
            'true_order': est_order},
    vb=3 )
dag = cc.fit(interventional_data_dict)
# Out:
# 	*** CausalChange (data=contexts, search=GraphSearch.COMBO, s=kci) ***
# Nodes: red, green, blue, current, ir_1, ir_2, ir_3, vis_1, vis_2, vis_3, pol_1, pol_2, angle_1, angle_2, l_11, l_12, l_21, l_22, l_31, l_32
# 	Using true next node: l_11
# 	1. Source: l_11	 current [14], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: l_21
# 	2. Source: l_21	 current [14, 16], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: l_22
# 	3. Source: l_22	 current [14, 16, 17], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: l_12
# 	4. Source: l_12	 current [14, 16, 17, 15], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: pol_1
# 	5. Source: pol_1	 current [14, 16, 17, 15, 10], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: l_32
# 	6. Source: l_32	 current [14, 16, 17, 15, 10, 19], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: pol_2
# 	7. Source: pol_2	 current [14, 16, 17, 15, 10, 19, 11], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: l_31
# 	8. Source: l_31	 current [14, 16, 17, 15, 10, 19, 11, 18], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: current
# 	9. Source: current	 current [14, 16, 17, 15, 10, 19, 11, 18, 3], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: green
# 	10. Source: green	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: angle_2
# 	11. Source: angle_2	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: red
# 	12. Source: red	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: angle_1
# 	13. Source: angle_1	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: blue
# 	14. Source: blue	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: ir_3
# 	15. Source: ir_3	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: ir_2
# 	16. Source: ir_2	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: ir_1
# 	17. Source: ir_1	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: vis_3
# 	18. Source: vis_3	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: vis_2
# 	19. Source: vis_2	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# 	Using true next node: vis_1
# 	20. Source: vis_1	 current [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7], true [14, 16, 17, 15, 10, 19, 11, 18, 3, 1, 13, 0, 12, 2, 6, 5, 4, 9, 8, 7]
# [edges-mmd-only] tau=0
# 	 child l_21: D0 invalid (-7.619041746254052e-05), skip
# 	 child l_22: D0 invalid (-0.0002236371422435379), skip
# 	 child l_12: D0 invalid (-0.0002559824437741165), skip
# 	 child pol_1: D0 invalid (-0.0003580177057473932), skip
# 	 child l_32: D0 invalid (-0.00036865061988424765), skip
# 	 child pol_2: D0 invalid (-0.0005007978166944981), skip
# 	 child l_31: D0 invalid (-0.0007120976676721514), skip
# 	 child current: base D0=0.7517
# 	  +edge l_11->current (spurious) (gain=0.075, D0=0.7517, D1=0.6957)
# 	  +edge l_21->current (spurious) (gain=0.038, D0=0.7517, D1=0.7232)
# 	  +edge l_22->current (spurious) (gain=0.006, D0=0.7517, D1=0.7470)
# 	  +edge l_12->current (spurious) (gain=0.042, D0=0.7517, D1=0.7201)
# 	  +edge pol_1->current (spurious) (gain=0.044, D0=0.7517, D1=0.7185)
# 	  +edge l_32->current (spurious) (gain=0.036, D0=0.7517, D1=0.7245)
# 	  +edge pol_2->current (spurious) (gain=0.061, D0=0.7517, D1=0.7060)
# 	  +edge l_31->current (spurious) (gain=0.034, D0=0.7517, D1=0.7265)
# 	 child green: base D0=0.5989
# 	  +edge l_11->green (spurious) (gain=0.002, D0=0.5989, D1=0.5980)
# 	  +edge l_21->green (spurious) (gain=0.004, D0=0.5989, D1=0.5967)
# 	  +edge l_22->green (spurious) (gain=0.001, D0=0.5989, D1=0.5981)
# 	  +edge l_12->green (spurious) (gain=0.006, D0=0.5989, D1=0.5953)
# 	  +edge pol_1->green (spurious) (gain=0.004, D0=0.5989, D1=0.5964)
# 	  +edge l_32->green (spurious) (gain=0.001, D0=0.5989, D1=0.5982)
# 	  +edge pol_2->green (spurious) (gain=0.003, D0=0.5989, D1=0.5969)
# 	  +edge l_31->green (spurious) (gain=0.003, D0=0.5989, D1=0.5969)
# 	  +edge current->green (rev) (gain=0.000, D0=0.5989, D1=0.8211)
# 	 child angle_2: base D0=0.0014
# 	  +edge l_11->angle_2 (spurious) (gain=0.000, D0=0.0014, D1=0.0015)
# 	  +edge l_21->angle_2 (spurious) (gain=0.000, D0=0.0014, D1=0.0015)
# 	  +edge l_22->angle_2 (spurious) (gain=0.000, D0=0.0014, D1=0.0014)
# 	  +edge l_12->angle_2 (spurious) (gain=0.029, D0=0.0014, D1=0.0014)
# 	  +edge pol_1->angle_2 (spurious) (gain=0.109, D0=0.0014, D1=0.0013)
# 	  +edge l_32->angle_2 (spurious) (gain=0.000, D0=0.0014, D1=0.0015)
# 	  +edge pol_2->angle_2 (causal) (gain=0.000, D0=0.0014, D1=0.1969)
# 	  +edge l_31->angle_2 (spurious) (gain=0.000, D0=0.0014, D1=0.0015)
# 	  +edge current->angle_2 (spurious) (gain=1.325, D0=0.0014, D1=-0.0005)
# 	  +edge green->angle_2 (spurious) (gain=0.724, D0=0.0014, D1=0.0004)
# 	 child red: base D0=0.6028
# 	  +edge l_11->red (spurious) (gain=0.004, D0=0.6028, D1=0.6005)
# 	  +edge l_21->red (spurious) (gain=0.003, D0=0.6028, D1=0.6012)
# 	  +edge l_22->red (spurious) (gain=0.003, D0=0.6028, D1=0.6012)
# 	  +edge l_12->red (spurious) (gain=0.007, D0=0.6028, D1=0.5985)
# 	  +edge pol_1->red (spurious) (gain=0.004, D0=0.6028, D1=0.6004)
# 	  +edge l_32->red (spurious) (gain=0.002, D0=0.6028, D1=0.6018)
# 	  +edge pol_2->red (spurious) (gain=0.001, D0=0.6028, D1=0.6023)
# 	  +edge l_31->red (spurious) (gain=0.001, D0=0.6028, D1=0.6021)
# 	  +edge current->red (rev) (gain=0.000, D0=0.6028, D1=0.8169)
# 	  +edge green->red (spurious) (gain=0.000, D0=0.6028, D1=0.7234)
# 	  +edge angle_2->red (spurious) (gain=0.001, D0=0.6028, D1=0.6022)
# 	 child angle_1: base D0=0.0006
# 	  +edge l_11->angle_1 (spurious) (gain=0.000, D0=0.0006, D1=0.0007)
# 	  +edge l_21->angle_1 (spurious) (gain=0.000, D0=0.0006, D1=0.0008)
# 	  +edge l_22->angle_1 (spurious) (gain=0.006, D0=0.0006, D1=0.0006)
# 	  +edge l_12->angle_1 (spurious) (gain=0.143, D0=0.0006, D1=0.0005)
# 	  +edge pol_1->angle_1 (causal) (gain=0.000, D0=0.0006, D1=0.2699)
# 	  +edge l_32->angle_1 (spurious) (gain=0.000, D0=0.0006, D1=0.0007)
# 	  +edge pol_2->angle_1 (spurious) (gain=0.000, D0=0.0006, D1=0.0006)
# 	  +edge l_31->angle_1 (spurious) (gain=0.000, D0=0.0006, D1=0.0007)
# 	  +edge current->angle_1 (spurious) (gain=2.039, D0=0.0006, D1=-0.0007)
# 	  +edge green->angle_1 (spurious) (gain=0.263, D0=0.0006, D1=0.0005)
# 	  +edge angle_2->angle_1 (spurious) (gain=0.006, D0=0.0006, D1=0.0006)
# 	  +edge red->angle_1 (spurious) (gain=0.000, D0=0.0006, D1=0.0007)
# 	 child blue: base D0=0.6035
# 	  +edge l_11->blue (spurious) (gain=0.006, D0=0.6035, D1=0.5996)
# 	  +edge l_21->blue (spurious) (gain=0.008, D0=0.6035, D1=0.5989)
# 	  +edge l_22->blue (spurious) (gain=0.009, D0=0.6035, D1=0.5979)
# 	  +edge l_12->blue (spurious) (gain=0.007, D0=0.6035, D1=0.5993)
# 	  +edge pol_1->blue (spurious) (gain=0.007, D0=0.6035, D1=0.5994)
# 	  +edge l_32->blue (spurious) (gain=0.007, D0=0.6035, D1=0.5994)
# 	  +edge pol_2->blue (spurious) (gain=0.007, D0=0.6035, D1=0.5994)
# 	  +edge l_31->blue (spurious) (gain=0.007, D0=0.6035, D1=0.5990)
# 	  +edge current->blue (rev) (gain=0.000, D0=0.6035, D1=0.8276)
# 	  +edge green->blue (spurious) (gain=0.000, D0=0.6035, D1=0.7227)
# 	  +edge angle_2->blue (spurious) (gain=0.007, D0=0.6035, D1=0.5993)
# 	  +edge red->blue (spurious) (gain=0.000, D0=0.6035, D1=0.7252)
# 	  +edge angle_1->blue (spurious) (gain=0.008, D0=0.6035, D1=0.5988)
# 	 child ir_3: base D0=0.6670
# 	  +edge l_11->ir_3 (spurious) (gain=0.006, D0=0.6670, D1=0.6631)
# 	  +edge l_21->ir_3 (spurious) (gain=0.002, D0=0.6670, D1=0.6654)
# 	  +edge l_22->ir_3 (spurious) (gain=0.004, D0=0.6670, D1=0.6646)
# 	  +edge l_12->ir_3 (spurious) (gain=0.008, D0=0.6670, D1=0.6615)
# 	  +edge pol_1->ir_3 (causal) (gain=0.000, D0=0.6670, D1=0.6684)
# 	  +edge l_32->ir_3 (causal) (gain=0.007, D0=0.6670, D1=0.6625)
# 	  +edge pol_2->ir_3 (causal) (gain=0.000, D0=0.6670, D1=0.6707)
# 	  +edge l_31->ir_3 (causal) (gain=0.001, D0=0.6670, D1=0.6662)
# 	  +edge current->ir_3 (spurious) (gain=0.478, D0=0.6670, D1=0.3479)
# 	  +edge green->ir_3 (causal) (gain=0.000, D0=0.6670, D1=0.6865)
# 	  +edge angle_2->ir_3 (spurious) (gain=0.006, D0=0.6670, D1=0.6631)
# 	  +edge red->ir_3 (causal) (gain=0.066, D0=0.6670, D1=0.6226)
# 	  +edge angle_1->ir_3 (spurious) (gain=0.005, D0=0.6670, D1=0.6639)
# 	  +edge blue->ir_3 (causal) (gain=0.000, D0=0.6670, D1=0.6939)
# 	 child ir_2: base D0=0.7092
# 	  +edge l_11->ir_2 (spurious) (gain=0.006, D0=0.7092, D1=0.7052)
# 	  +edge l_21->ir_2 (causal) (gain=0.003, D0=0.7092, D1=0.7071)
# 	  +edge l_22->ir_2 (causal) (gain=0.005, D0=0.7092, D1=0.7058)
# 	  +edge l_12->ir_2 (spurious) (gain=0.009, D0=0.7092, D1=0.7028)
# 	  +edge pol_1->ir_2 (spurious) (gain=0.004, D0=0.7092, D1=0.7066)
# 	  +edge l_32->ir_2 (spurious) (gain=0.006, D0=0.7092, D1=0.7051)
# 	  +edge pol_2->ir_2 (spurious) (gain=0.001, D0=0.7092, D1=0.7087)
# 	  +edge l_31->ir_2 (spurious) (gain=0.002, D0=0.7092, D1=0.7080)
# 	  +edge current->ir_2 (spurious) (gain=0.374, D0=0.7092, D1=0.4441)
# 	  +edge green->ir_2 (causal) (gain=0.000, D0=0.7092, D1=0.7390)
# 	  +edge angle_2->ir_2 (spurious) (gain=0.012, D0=0.7092, D1=0.7009)
# 	  +edge red->ir_2 (causal) (gain=0.003, D0=0.7092, D1=0.7073)
# 	  +edge angle_1->ir_2 (spurious) (gain=0.009, D0=0.7092, D1=0.7026)
# 	  +edge blue->ir_2 (causal) (gain=0.000, D0=0.7092, D1=0.7410)
# 	  +edge ir_3->ir_2 (spurious) (gain=0.953, D0=0.7092, D1=0.0331)
# 	 child ir_1: base D0=0.7171
# 	  +edge l_11->ir_1 (causal) (gain=0.006, D0=0.7171, D1=0.7132)
# 	  +edge l_21->ir_1 (spurious) (gain=0.003, D0=0.7171, D1=0.7152)
# 	  +edge l_22->ir_1 (spurious) (gain=0.004, D0=0.7171, D1=0.7142)
# 	  +edge l_12->ir_1 (causal) (gain=0.009, D0=0.7171, D1=0.7107)
# 	  +edge pol_1->ir_1 (spurious) (gain=0.004, D0=0.7171, D1=0.7145)
# 	  +edge l_32->ir_1 (spurious) (gain=0.006, D0=0.7171, D1=0.7131)
# 	  +edge pol_2->ir_1 (spurious) (gain=0.001, D0=0.7171, D1=0.7165)
# 	  +edge l_31->ir_1 (spurious) (gain=0.001, D0=0.7171, D1=0.7163)
# 	  +edge current->ir_1 (spurious) (gain=0.337, D0=0.7171, D1=0.4757)
# 	  +edge green->ir_1 (causal) (gain=0.000, D0=0.7171, D1=0.7414)
# 	  +edge angle_2->ir_1 (spurious) (gain=0.014, D0=0.7171, D1=0.7075)
# 	  +edge red->ir_1 (causal) (gain=0.000, D0=0.7171, D1=0.7188)
# 	  +edge angle_1->ir_1 (spurious) (gain=0.008, D0=0.7171, D1=0.7111)
# 	  +edge blue->ir_1 (causal) (gain=0.000, D0=0.7171, D1=0.7441)
# 	  +edge ir_3->ir_1 (spurious) (gain=0.955, D0=0.7171, D1=0.0324)
# 	  +edge ir_2->ir_1 (spurious) (gain=0.904, D0=0.7171, D1=0.0688)
# 	 child vis_3: base D0=0.6980
# 	  +edge l_11->vis_3 (spurious) (gain=0.006, D0=0.6980, D1=0.6939)
# 	  +edge l_21->vis_3 (spurious) (gain=0.000, D0=0.6980, D1=0.6980)
# 	  +edge l_22->vis_3 (spurious) (gain=0.000, D0=0.6980, D1=0.6979)
# 	  +edge l_12->vis_3 (spurious) (gain=0.001, D0=0.6980, D1=0.6975)
# 	  +edge pol_1->vis_3 (causal) (gain=0.000, D0=0.6980, D1=0.7022)
# 	  +edge l_32->vis_3 (causal) (gain=0.005, D0=0.6980, D1=0.6941)
# 	  +edge pol_2->vis_3 (causal) (gain=0.000, D0=0.6980, D1=0.7002)
# 	  +edge l_31->vis_3 (causal) (gain=0.000, D0=0.6980, D1=0.6980)
# 	  +edge current->vis_3 (spurious) (gain=0.216, D0=0.6980, D1=0.5472)
# 	  +edge green->vis_3 (causal) (gain=0.001, D0=0.6980, D1=0.6973)
# 	  +edge angle_2->vis_3 (spurious) (gain=0.007, D0=0.6980, D1=0.6931)
# 	  +edge red->vis_3 (causal) (gain=0.000, D0=0.6980, D1=0.7065)
# 	  +edge angle_1->vis_3 (spurious) (gain=0.010, D0=0.6980, D1=0.6910)
# 	  +edge blue->vis_3 (causal) (gain=0.129, D0=0.6980, D1=0.6078)
# 	  +edge ir_3->vis_3 (spurious) (gain=0.451, D0=0.6980, D1=0.3833)
# 	  +edge ir_2->vis_3 (spurious) (gain=0.550, D0=0.6980, D1=0.3141)
# 	  +edge ir_1->vis_3 (spurious) (gain=0.559, D0=0.6980, D1=0.3076)
# 	 child vis_2: base D0=0.7383
# 	  +edge l_11->vis_2 (spurious) (gain=0.008, D0=0.7383, D1=0.7326)
# 	  +edge l_21->vis_2 (causal) (gain=0.001, D0=0.7383, D1=0.7372)
# 	  +edge l_22->vis_2 (causal) (gain=0.002, D0=0.7383, D1=0.7366)
# 	  +edge l_12->vis_2 (spurious) (gain=0.002, D0=0.7383, D1=0.7371)
# 	  +edge pol_1->vis_2 (spurious) (gain=0.000, D0=0.7383, D1=0.7379)
# 	  +edge l_32->vis_2 (spurious) (gain=0.006, D0=0.7383, D1=0.7335)
# 	  +edge pol_2->vis_2 (spurious) (gain=0.003, D0=0.7383, D1=0.7363)

# %%
est_dag_nx = dag
dg = nx.to_numpy_array(dag)
true_nx = nx.from_numpy_array(true_dag, create_using=nx.DiGraph)
print(precision(dg, true_dag))
print(f'Precision: {precision(dg, true_dag)}')
print(f'Recall: {recall(dg, true_dag)}')
print(f'True Order : {[i for i in nx.topological_sort(nx.from_numpy_array(true_dag, create_using=nx.DiGraph))]}')
print(f'Est Order : {[i for i in nx.topological_sort(dag)]}')
est_order = nx.topological_sort(dag)
for i in nx.topological_sort(dag):
    print(f'{variables[i]}: pre={len(list(true_nx.predecessors(i)))}, succ={len(list(true_nx.successors(i)))}')
# Out:
# 0.32857142857142857
# Precision: 0.32857142857142857
# Recall: 0.5897435897435898
# True Order : [0, 1, 2, 10, 11, 14, 15, 16, 17, 18, 19, 3, 12, 13, 4, 7, 5, 8, 6, 9]
# Est Order : [0, 10, 11, 14, 15, 16, 17, 18, 19, 1, 2, 3, 4, 5, 6, 7, 8, 9, 12, 13]
# red: pre=0, succ=7
# pol_1: pre=0, succ=3
# pol_2: pre=0, succ=3
# l_11: pre=0, succ=2
# l_12: pre=0, succ=2
# l_21: pre=0, succ=2
# l_22: pre=0, succ=2
# l_31: pre=0, succ=2
# l_32: pre=0, succ=2
# green: pre=0, succ=7
# blue: pre=0, succ=7
# current: pre=3, succ=0
# ir_1: pre=5, succ=0
# ir_2: pre=5, succ=0
# ir_3: pre=7, succ=0
# vis_1: pre=5, succ=0
# vis_2: pre=5, succ=0
# vis_3: pre=7, succ=0
# angle_1: pre=1, succ=0
# angle_2: pre=1, succ=0

# %%
import src.ut_igsp as ut_igsp
# Out:
# /home/juan/ETH/causal-chamber-paper/notebooks/lib/python3.8/site-packages/causaldag/utils/ci_tests/gauss_ci.py:10: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def numba_inv(A):

# %%
alphas = np.linspace(1e-4,1e-2,10)
betas = np.linspace(1e-4,1e-2,10)

# %%
# %%time
np.random.seed(42) # This doesn't fix the output of UT-IGSP below; I don't know how they manage the random state
dags = np.zeros((len(alphas), len(betas), len(variables), len(variables)))
for i,alpha in enumerate(alphas):
    for j,beta in enumerate(betas):
        print((i,j), end="\r")
        dag, _ = ut_igsp.fit(interventional_data, alpha, alpha, test='gauss')
        dags[i,j] = dag
# Out:
# (1, 0)
# /home/juan/ETH/causal-chamber-paper/notebooks/lib/python3.8/site-packages/causaldag/utils/invariance_tests/gauss_invariance.py:119: RuntimeWarning: divide by zero encountered in scalar divide
#   ftest_stat = var1 / var2
# CPU times: user 7min 17s, sys: 18min 14s, total: 25min 32s
# Wall time: 3min 21s

# %% [markdown]
# #### Compute precision and recall for each dag

# %%
metrics = np.zeros((len(alphas), len(betas), 2))
for i,alpha in enumerate(alphas):
    for j,beta in enumerate(betas):
        dag = dags[i,j]
        metrics[i,j,0] = precision(dag, true_dag)
        metrics[i,j,1] = recall(dag, true_dag)
# Plot results as sanity check
plt.subplot(131)
plt.imshow(metrics[:,:,0],vmin=0,vmax=1)
plt.title("Precision")

plt.subplot(132)
plt.imshow(metrics[:,:,1],vmin=0,vmax=1)
plt.title("Recall")
# Out:
# Text(0.5, 1.0, 'Recall')

# %% [markdown]
# #### Select best DAG for the figure as minimum L2-distance to $(1,1)$

# %%
# Compute L2 - distance
l2_dist = np.sqrt(((1 - metrics)**2).sum(axis=2))
plt.imshow(l2_dist)
plt.title("L2-dist to (1,1)")
# Select best
i_best,j_best = sempler.utils.argmin(l2_dist)
best_dag = dags[i_best,j_best]
# Print stats for figure
prec,rec = metrics[i_best,j_best]
assert prec == precision(best_dag,true_dag)
assert rec == recall(best_dag,true_dag)
alpha,beta = alphas[i_best], betas[j_best]
print("Best", (i_best,j_best))
print(f"  precision = {prec:.2f}, recall = {rec:.2f}")
print(f"  alpha = {alpha}, beta = {beta}\n\n")
# Plot graph and tikz output
sempler.plot.plot_graph(best_dag, labels=variables)
print(graph_to_tikz(best_dag, radius=2, labels=[latex_name(v) for v in variables], bend=40, undirected="thick"))
# Out:
# Best (4, 1)
#   precision = 0.51, recall = 0.64
#   alpha = 0.0045000000000000005, beta = 0.0012000000000000001
#     \begin{tikzpicture}
#         \node[circle, inner sep=0.12em] (0) at (-0.618, 1.902) {$R$};
#         \node[circle, inner sep=0.12em] (1) at (-1.176, 1.618) {$G$};
#         \node[circle, inner sep=0.12em] (2) at (-1.618, 1.176) {$B$};
#         \node[circle, inner sep=0.12em] (3) at (-1.902, 0.618) {$\tilde{C}$};
#         \node[circle, inner sep=0.12em] (4) at (-2.000, -0.000) {$\tilde{I}_1$};
#         \node[circle, inner sep=0.12em] (5) at (-1.902, -0.618) {$\tilde{I}_2$};
#         \node[circle, inner sep=0.12em] (6) at (-1.618, -1.176) {$\tilde{I}_3$};
#         \node[circle, inner sep=0.12em] (7) at (-1.176, -1.618) {$\tilde{V}_1$};
#         \node[circle, inner sep=0.12em] (8) at (-0.618, -1.902) {$\tilde{V}_2$};
#         \node[circle, inner sep=0.12em] (9) at (0.000, -2.000) {$\tilde{V}_3$};
#         \node[circle, inner sep=0.12em] (10) at (0.618, -1.902) {$\theta_1$};
#         \node[circle, inner sep=0.12em] (11) at (1.176, -1.618) {$\theta_2$};
#         \node[circle, inner sep=0.12em] (12) at (1.618, -1.176) {$\tilde{\theta}_1$};
#         \node[circle, inner sep=0.12em] (13) at (1.902, -0.618) {$\tilde{\theta}_2$};
#         \node[circle, inner sep=0.12em] (14) at (2.000, 0.000) {$L_{11}$};
#         \node[circle, inner sep=0.12em] (15) at (1.902, 0.618) {$L_{12}$};
#         \node[circle, inner sep=0.12em] (16) at (1.618, 1.176) {$L_{21}$};
#         \node[circle, inner sep=0.12em] (17) at (1.176, 1.618) {$L_{22}$};
#         \node[circle, inner sep=0.12em] (18) at (0.618, 1.902) {$L_{31}$};
#         \node[circle, inner sep=0.12em] (19) at (0.000, 2.000) {$L_{32}$};
#         \begin{scope}[]
#             \draw[->, bend left=28] (0) edge (3);
#             \draw[->, bend left=24] (0) edge (4);
#             \draw[->, bend left=20] (0) edge (5);
#             \draw[->, bend left=16] (0) edge (6);
#             \draw[->, bend left=12] (0) edge (7);
#             \draw[->, bend left=7] (0) edge (8);
#             \draw[->, bend left=3] (0) edge (9);
#             \draw[->, bend right=4] (0) edge (11);
#             \draw[->, bend left=32] (1) edge (3);
#             \draw[->, bend left=28] (1) edge (4);
#             \draw[->, bend left=24] (1) edge (5);
#             \draw[->, bend left=20] (1) edge (6);
#             \draw[->, bend left=16] (1) edge (7);
#             \draw[->, bend left=12] (1) edge (8);
#             \draw[->, bend left=7] (1) edge (9);
#             \draw[->, bend right=0] (1) edge (11);
#             \draw[->, bend left=36] (2) edge (3);
#             \draw[->, bend left=32] (2) edge (4);
#             \draw[->, bend left=28] (2) edge (5);
#             \draw[->, bend left=24] (2) edge (6);
#             \draw[->, bend left=20] (2) edge (7);
#             \draw[->, bend left=16] (2) edge (8);
#             \draw[->, bend left=12] (2) edge (9);
#             \draw[->, bend left=3] (2) edge (11);
#             \draw[->, bend left=28] (4) edge (7);
#             \draw[->, bend right=32] (5) edge (3);
#             \draw[->, bend right=36] (5) edge (4);
#             \draw[->, bend left=32] (5) edge (7);
#             \draw[->, bend left=28] (5) edge (8);
#             \draw[->, bend right=4] (5) edge (16);
#             \draw[->, bend right=28] (6) edge (3);
#             \draw[->, bend right=32] (6) edge (4);
#             \draw[->, bend right=36] (6) edge (5);
#             \draw[->, bend left=36] (6) edge (7);
#             \draw[->, bend left=32] (6) edge (8);
#             \draw[->, bend left=20] (6) edge (11);
#             \draw[->, bend left=36] (7) edge (8);
#             \draw[->, bend right=20] (8) edge (3);
#             \draw[->, bend right=28] (9) edge (6);
#             \draw[->, bend right=32] (9) edge (7);
#             \draw[->, bend right=36] (9) edge (8);
#             \draw[->, bend left=32] (9) edge (11);
#             \draw[->, bend right=24] (10) edge (6);
#             \draw[->, bend right=36] (10) edge (9);
#             \draw[->, bend left=32] (10) edge (12);
#             \draw[->, bend left=28] (10) edge (13);
#             \draw[->, bend left=32] (11) edge (13);
#             \draw[->, bend left=36] (12) edge (13);
#             \draw[->, bend left=16] (15) edge (1);
#         \end{scope}
#     \end{tikzpicture}
