# %%
from benchmarks.synthetic.generator_time import sample_spacetime_synthetic

res = sample_spacetime_synthetic(
    n_datasets=4,
    n_samples=120,
    n_nodes=3,
    edge_prob=0.4,
    seed=1,
    tau_max=2,
    n_changepoints=2,
    n_regimes=2,
    n_context_clusters=2,
    min_segment_length=30,
)

print(res.df.shape)
print("changepoints:", res.changepoints)
print("interval regimes:", res.interval_regime_labels)
print("WCG edges:", res.true_wcg.number_of_edges())
print("summary DAG edges:", res.true_summary_dag.number_of_edges())
print(res.df.head())
# Out:
# (480, 4)
# changepoints: [41, 79]
# interval regimes: [0, 1, 0]
# WCG edges: 10
# summary DAG edges: 5
#          X0        X1        X2  context
# 0  0.142697 -0.501121 -0.567215        0
# 1  0.237848  0.356441 -0.047534        0
# 2  0.244117 -0.217591 -0.371493        0
# 3 -0.120144 -0.591507  0.003036        0
# 4 -0.708115 -0.510659  0.938128        0
